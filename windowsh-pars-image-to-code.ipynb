# %%
# !pip install numpy
# !pip install Pillow
# !pip install matplotlib.pyplot
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.22.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (8.4.0)
# ERROR: Could not find a version that satisfies the requirement matplotlib.pyplot (from versions: none)
# ERROR: No matching distribution found for matplotlib.pyplot

# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
# Открытие и отображение файла
file_name = 'PoisonGlass.png'
img = np.array(Image.open(file_name).convert('RGB'))
fig, ax = plt.subplots()
ax.imshow(img)
ax.set_title(file_name)
plt.show()

# %%
# Команды отрисовки для windows.h
for i in range(0, img.shape[0]):
    for j in range(0, img.shape[1]):
        if (img[i][j][0] != 0) or (img[i][j][0] != 0) or (img[i][j][0] != 0):
          temp = "SetPixel(hdc, x + " + str(j) + ", y + " + str(i) + ", RGB(" + str(img[i][j][0]) + ", " + str(img[i][j][1]) + ", " + str(img[i][j][2]) + "));"
          print(temp)
          file = open("output", w)
          file.write
# Out:
# SetPixel(hdc, x + 14, y + 0, RGB(215, 118, 67));
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-f0110e228418> in <cell line: 2>()
#       5           temp = "SetPixel(hdc, x + " + str(j) + ", y + " + str(i) + ", RGB(" + str(img[i][j][0]) + ", " + str(img[i][j][1]) + ", " + str(img[i][j][2]) + "));"
#       6           print(temp)
# ----> 7           file = open(str('output' + file_name), w)
#       8           file.write
#
# NameError: name 'w' is not defined

# %%
# Команды скрытия для windows.h
for i in range(0, img.shape[0]):
    for j in range(0, img.shape[1]):
        if (img[i][j][0] != 0) or (img[i][j][0] != 0) or (img[i][j][0] != 0):
          temp = "SetPixel(hdc, x + " + str(j) + ", y + " + str(i) + ", RGB(12, 13, 13));"
          print(temp)

# %%
# Матрицы цветов
fileR = open(file_name[:-4] + "-outputR.txt", 'w')
fileG = open(file_name[:-4] + "-outputG.txt", 'w')
fileB = open(file_name[:-4] + "-outputB.txt", 'w')
for i in range(0, img.shape[0]):
    tempR = "{"
    tempG = "{"
    tempB = "{"
    for j in range(0, img.shape[1]):
      tempR += str(img[i][j][0])
      tempG += str(img[i][j][1])
      tempB += str(img[i][j][2])
      if (j <= img.shape[1] - 1):
        tempR += ", "
        tempG += ", "
        tempB += ", "
    tempR += "}, \n"
    tempG += "}, \n"
    tempB += "}, \n"
    fileR.write(tempR)
    fileG.write(tempG)
    fileB.write(tempB)
